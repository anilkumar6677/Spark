# %% [markdown]
# Hello this is Pyspark Dev Env

# %%
data = [
    (1, "Alice", 29, "New York"),
    (2, "Bob", 35, "San Francisco"),
    (3, "Charlie", 23, "Seattle"),
    (4, "Diana", 41, "Chicago")
]

columns = ["id", "name", "age", "city"]

df = spark.createDataFrame(data,columns)
df.show()

# %%
fildf= df.filter("age > 30")
fildf.show()
